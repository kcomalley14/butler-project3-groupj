# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 542B-68B5
#
#  Directory of C:\Users\Owner\Butler\butler-project3-groupj
#
# 03/01/2021  09:39 PM    <DIR>          .
# 03/01/2021  09:39 PM    <DIR>          ..
# 02/27/2021  07:35 PM    <DIR>          .ipynb_checkpoints
# 03/01/2021  08:27 PM        25,479,985 Butler Final Project.pptx
# 02/27/2021  12:43 PM            13,122 Butler FinalProject GroupJ.docx
# 02/27/2021  07:38 PM    <DIR>          cleandata
# 02/27/2021  07:35 PM         2,127,027 Metro_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_mon.csv
# 03/01/2021  09:39 PM            58,025 PostgresData.ipynb
# 03/01/2021  08:18 PM                67 Procfile
# 02/27/2021  12:44 PM               775 README.md
# 03/01/2021  05:18 PM                67 requirements.txt
# 03/01/2021  08:18 PM               143 setup.sh
# 03/01/2021  07:10 PM               365 Transform.sql
# 03/01/2021  08:18 PM               483 zillow-app.py
# ...

# %%
#Pull data from trimmed CSV intpo a dataframe

df = pd.read_csv('Zip_zUpdated_sm_sa_mon.csv',encoding = 'utf-8')

# %%
df['ZIP'] = df['ZIP'].astype(str).str.zfill(5)

# %%
df
# Out:
#          ZIP State              City                             Metro  \
# 0      10025    NY          New York       New York-Newark-Jersey City
# 1      60657    IL           Chicago          Chicago-Naperville-Elgin
# 2      10023    NY          New York       New York-Newark-Jersey City
# 3      77494    TX              Katy  Houston-The Woodlands-Sugar Land
# 4      60614    IL           Chicago          Chicago-Naperville-Elgin
# ...      ...   ...               ...                               ...
# 30291  52204    IA             Amana                               NaN
# 30292  63875    MO             Rives                           Kennett
# 30293  72630    AR      Diamond City                          Harrison
# 30294    801    UT  Charlotte Amalie                               NaN
# 30295    822    LA         Choudrant                            Ruston
#
#             CountyName    2010Jan    2010Feb    2010Mar    2010Apr    2010May  \
# ...

# %%
print(df)
# Out:
#          ZIP State              City                             Metro  \
# 0      10025    NY          New York       New York-Newark-Jersey City
# 1      60657    IL           Chicago          Chicago-Naperville-Elgin
# 2      10023    NY          New York       New York-Newark-Jersey City
# 3      77494    TX              Katy  Houston-The Woodlands-Sugar Land
# 4      60614    IL           Chicago          Chicago-Naperville-Elgin
# ...      ...   ...               ...                               ...
# 30291  52204    IA             Amana                               NaN
# 30292  63875    MO             Rives                           Kennett
# 30293  72630    AR      Diamond City                          Harrison
# 30294  00801    UT  Charlotte Amalie                               NaN
# 30295  00822    LA         Choudrant                            Ruston
#
#             CountyName    2010Jan    2010Feb    2010Mar    2010Apr    2010May  \
# ...

# %%
LimitdfIN = df.loc[df['State'].isin(['IN'])]
print(LimitdfIN)
# Out:
#          ZIP State            City                         Metro  \
# 174    47906    IN  West Lafayette      Lafayette-West Lafayette
# 186    46307    IN     Crown Point      Chicago-Naperville-Elgin
# 243    46227    IN    Indianapolis  Indianapolis-Carmel-Anderson
# 395    46143    IN       Greenwood  Indianapolis-Carmel-Anderson
# 560    47150    IN      New Albany   Louisville/Jefferson County
# ...      ...   ...             ...                           ...
# 30225  46942    IN      Logansport                    Logansport
# 30229  47986    IN          Oxford      Lafayette-West Lafayette
# 30238  47556    IN       Ferdinand                        Jasper
# 30241  47683    IN      Somerville                           NaN
# 30278  47865    IN        Carlisle                   Terre Haute
#
#               CountyName   2010Jan   2010Feb   2010Mar   2010Apr   2010May  \
# 174    Tippecanoe County  180353.0  179117.0  177828.0  177335.0  177451.0
# ...

# %%
#Transpose data for IN

INData =LimitdfIN.set_index(['ZIP', 'State','City','Metro', 'CountyName'  ]).stack().reset_index()
 
INData.head()
# Out:
#      ZIP State            City                     Metro         CountyName  \
# 0  47906    IN  West Lafayette  Lafayette-West Lafayette  Tippecanoe County
# 1  47906    IN  West Lafayette  Lafayette-West Lafayette  Tippecanoe County
# 2  47906    IN  West Lafayette  Lafayette-West Lafayette  Tippecanoe County
# 3  47906    IN  West Lafayette  Lafayette-West Lafayette  Tippecanoe County
# 4  47906    IN  West Lafayette  Lafayette-West Lafayette  Tippecanoe County
#
#    level_5         0
# 0  2010Jan  180353.0
# 1  2010Feb  179117.0
# 2  2010Mar  177828.0
# 3  2010Apr  177335.0
# 4  2010May  177451.0

# %%
from sqlalchemy import create_engine
engine = create_engine('postgres://ktzvdgknpndezh:eab7e0f8adf1173460ffd2ca67eaccb46eb455ed1d958d88d12cad1ad1d89969@ec2-54-209-43-223.compute-1.amazonaws.com:5432/ddp1fm5s697u67', echo=False)
INData.to_sql('ZillowINData', con=engine,index = False)

# %%
LimitdfMW = df.loc[df['State'].isin(['IN','KY','IL','OH','MI'])]
print(LimitdfIN)
# Out:
#          ZIP State            City                         Metro  \
# 174    47906    IN  West Lafayette      Lafayette-West Lafayette
# 186    46307    IN     Crown Point      Chicago-Naperville-Elgin
# 243    46227    IN    Indianapolis  Indianapolis-Carmel-Anderson
# 395    46143    IN       Greenwood  Indianapolis-Carmel-Anderson
# 560    47150    IN      New Albany   Louisville/Jefferson County
# ...      ...   ...             ...                           ...
# 30225  46942    IN      Logansport                    Logansport
# 30229  47986    IN          Oxford      Lafayette-West Lafayette
# 30238  47556    IN       Ferdinand                        Jasper
# 30241  47683    IN      Somerville                           NaN
# 30278  47865    IN        Carlisle                   Terre Haute
#
#               CountyName   2010Jan   2010Feb   2010Mar   2010Apr   2010May  \
# 174    Tippecanoe County  180353.0  179117.0  177828.0  177335.0  177451.0
# ...

# %%
MWData =LimitdfMW.set_index(['ZIP','State','City','Metro', 'CountyName'  ]).stack().reset_index()
 
MWData.head()
# Out:
#      ZIP State     City                     Metro   CountyName  level_5  \
# 0  60657    IL  Chicago  Chicago-Naperville-Elgin  Cook County  2010Jan
# 1  60657    IL  Chicago  Chicago-Naperville-Elgin  Cook County  2010Feb
# 2  60657    IL  Chicago  Chicago-Naperville-Elgin  Cook County  2010Mar
# 3  60657    IL  Chicago  Chicago-Naperville-Elgin  Cook County  2010Apr
# 4  60657    IL  Chicago  Chicago-Naperville-Elgin  Cook County  2010May
#
#           0
# 0  737657.0
# 1  743413.0
# 2  736204.0
# 3  737841.0
# 4  729740.0

# %%
from sqlalchemy import create_engine
engine = create_engine('postgres://ktzvdgknpndezh:eab7e0f8adf1173460ffd2ca67eaccb46eb455ed1d958d88d12cad1ad1d89969@ec2-54-209-43-223.compute-1.amazonaws.com:5432/ddp1fm5s697u67', echo=False)
MWData.to_sql('ZillowMWData', con=engine,index = False)

# %%
# NewData =Limitdf.set_index(['RegionID','SizeRank', 'RegionName', 'RegionType', 'StateName', 'State','City','Metro', 'CountyName'  ]).stack().reset_index()
 
# NewData.head()

USData =df.set_index(['ZIP','State','City','Metro', 'CountyName'  ]).stack().reset_index()
 
USData.head()

print(USData)
# Out:
#            ZIP State       City                        Metro       CountyName  \
# 0        10025    NY   New York  New York-Newark-Jersey City  New York County
# 1        10025    NY   New York  New York-Newark-Jersey City  New York County
# 2        10025    NY   New York  New York-Newark-Jersey City  New York County
# 3        10025    NY   New York  New York-Newark-Jersey City  New York County
# 4        10025    NY   New York  New York-Newark-Jersey City  New York County
# ...        ...   ...        ...                          ...              ...
# 3836345  00822    LA  Choudrant                       Ruston   Lincoln Parish
# 3836346  00822    LA  Choudrant                       Ruston   Lincoln Parish
# 3836347  00822    LA  Choudrant                       Ruston   Lincoln Parish
# 3836348  00822    LA  Choudrant                       Ruston   Lincoln Parish
# 3836349  00822    LA  Choudrant                       Ruston   Lincoln Parish
#
#          level_5          0
# ...

# %%
# NewData.to_csv("cleandata/zipdata.csv")

from sqlalchemy import create_engine
engine = create_engine('postgres://ktzvdgknpndezh:eab7e0f8adf1173460ffd2ca67eaccb46eb455ed1d958d88d12cad1ad1d89969@ec2-54-209-43-223.compute-1.amazonaws.com:5432/ddp1fm5s697u67', echo=False)


USData.to_sql('FullUSZillow', con=engine,index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# ...
